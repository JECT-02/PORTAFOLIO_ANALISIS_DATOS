# %% [markdown]
# # 06 Backtesting
#
# Backtesting rolling window y test de Kupiec.

# %%
import pandas as pd
from pathlib import Path

gold_dir = Path('../data/gold')

# %%
bt_results = pd.read_csv(gold_dir / 'backtest_results.csv')
bt_results
