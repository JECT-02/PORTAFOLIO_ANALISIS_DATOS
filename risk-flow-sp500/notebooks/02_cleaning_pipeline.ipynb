# %% [markdown]
# # 02 Cleaning Pipeline
#
# Limpieza de datos de bronze a silver.

# %%
import sys
sys.path.append('..')
import pandas as pd
from src.clean_data import run_clean_pipeline
from pathlib import Path

silver_dir = Path('../data/silver')

# %%
run_clean_pipeline()

# %%
prices = pd.read_parquet(silver_dir / 'prices.parquet')
prices.head()

# %%
returns = pd.read_parquet(silver_dir / 'returns.parquet')
returns.head()
